# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Iris dataset
#
# The iris dataset is one of the most popular dataset in machine learning community. You can get the dataset and description at https://archive.ics.uci.edu/ml/datasets/iris.
#
# The following picture shows the types of iris and what petals and sepals are. (Source: Datacamp)
#
# ![](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png)

# %% [markdown]
# ## Reading dataset and bookkeepings

# %%
# since we do not have column names, we have to provide them manually
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
iris = pd.read_csv('iris.data.csv', names=column_names)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
lookup_iris = dict(enumerate(iris['class'].unique()))
lookup_iris
# Out:
# {0: 'Iris-setosa', 1: 'Iris-versicolor', 2: 'Iris-virginica'}

# %%
inverse_lookup_iris = {v: k for k, v in lookup_iris.items()}
inverse_lookup_iris
# Out:
# {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}

# %%
iris['label'] = iris['class'].apply(lambda v: inverse_lookup_iris[v])
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class  label
# 0           5.1          3.5           1.4          0.2  Iris-setosa      0
# 1           4.9          3.0           1.4          0.2  Iris-setosa      0
# 2           4.7          3.2           1.3          0.2  Iris-setosa      0
# 3           4.6          3.1           1.5          0.2  Iris-setosa      0
# 4           5.0          3.6           1.4          0.2  Iris-setosa      0

# %%
X = iris[column_names[:-1]]
y = iris['label']
print('X', '-'*60, X.head(), sep='\n')
print('y', '-'*6, y.head(), sep='\n')
# Out:
# X
# ------------------------------------------------------------
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# y
# ------
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int64

# %% [markdown]
# ### Alternate way of reading data from `sklearn`
#
# `sklearn` includes iris dataset! We the following code, you can read X's and y's (in ndarray).

# %%
from sklearn import datasets
iris_dataset = datasets.load_iris()
X = iris_dataset.data
y = iris_dataset.target
print('X', '-'*60, X[:5], sep='\n')
print('y', '-'*6, y[:5], sep='\n')
# Out:
# X
# ------------------------------------------------------------
# [[ 5.1  3.5  1.4  0.2]
#  [ 4.9  3.   1.4  0.2]
#  [ 4.7  3.2  1.3  0.2]
#  [ 4.6  3.1  1.5  0.2]
#  [ 5.   3.6  1.4  0.2]]
# y
# ------
# [0 0 0 0 0]

# %% [markdown]
# Now you can make DataFrame from ndarray.

# %%
X = pd.DataFrame(X, columns=column_names[:-1])
y = pd.Series(y)
print('X', '-'*60, X.head(), sep='\n')
print('y', '-'*6, y.head(), sep='\n')
# Out:
# X
# ------------------------------------------------------------
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# y
# ------
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %% [markdown]
# ## Examining the data

# %% [markdown]
# ### Scatter plot matrix (or pair plot)

# %%
from matplotlib import cm
# gnuplot's traditional pm3d scheme (black-blue-red-yellow)
cmap = cm.get_cmap('gnuplot')
scatter = pd.plotting.scatter_matrix(X, c=y, cmap=cmap)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib.colors import ListedColormap
# manually specify a color map: red, green, blue
cmap2 = ListedColormap(['#ff0000', '#00ff00', '#0000ff'])
scatter = pd.plotting.scatter_matrix(X, c=y, cmap=cmap2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 3D scatter plots

# %%
# plotting a 3D scatter plot
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X['petal_width'], X['petal_length'], X['sepal_width'], c=y, marker='o', cmap=cmap)
ax.set_xlabel('petal_width')
ax.set_ylabel('petal_length')
ax.set_zlabel('sepal_width')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Correlation

# %%
corr = X.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
# heatmap
cmap = cm.get_cmap('seismic')
plt.matshow(corr, cmap=cmap)
plt.xticks(range(len(corr.columns)), corr.columns)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
# heatmap with numbers
(corr.style.background_gradient(cmap=cmap)
     .set_properties(**{'color': '#ffffff'})
)
# Out:
# <style  type="text/css" >
#     #T_0a562394_b440_11e7_b87d_784f4377b2barow0_col0 {
#             background-color:  #800000;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow0_col1 {
#             background-color:  #0000e9;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow0_col2 {
#             background-color:  #ae0000;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow0_col3 {
#             background-color:  #c30000;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow1_col0 {
#             background-color:  #00004c;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow1_col1 {
#             background-color:  #800000;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow1_col2 {
#             background-color:  #00004c;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow1_col3 {
#             background-color:  #00004c;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow2_col0 {
#             background-color:  #ba0000;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow2_col1 {
#             background-color:  #00004c;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow2_col2 {
#             background-color:  #800000;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow2_col3 {
#             background-color:  #8e0000;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow3_col0 {
#             background-color:  #d30000;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow3_col1 {
#             background-color:  #00006b;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow3_col2 {
#             background-color:  #8c0000;
#             color:  #ffffff;
#         }    #T_0a562394_b440_11e7_b87d_784f4377b2barow3_col3 {
#             background-color:  #800000;
#             color:  #ffffff;
#         }</style>
# <table id="T_0a562394_b440_11e7_b87d_784f4377b2ba" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >sepal_length</th>
#         <th class="col_heading level0 col1" >sepal_width</th>
#         <th class="col_heading level0 col2" >petal_length</th>
#         <th class="col_heading level0 col3" >petal_width</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_0a562394_b440_11e7_b87d_784f4377b2balevel0_row0" class="row_heading level0 row0" >sepal_length</th>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow0_col0" class="data row0 col0" >1</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow0_col1" class="data row0 col1" >-0.109369</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow0_col2" class="data row0 col2" >0.871754</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow0_col3" class="data row0 col3" >0.817954</td>
#     </tr>    <tr>
#         <th id="T_0a562394_b440_11e7_b87d_784f4377b2balevel0_row1" class="row_heading level0 row1" >sepal_width</th>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow1_col0" class="data row1 col0" >-0.109369</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow1_col1" class="data row1 col1" >1</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow1_col2" class="data row1 col2" >-0.420516</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow1_col3" class="data row1 col3" >-0.356544</td>
#     </tr>    <tr>
#         <th id="T_0a562394_b440_11e7_b87d_784f4377b2balevel0_row2" class="row_heading level0 row2" >petal_length</th>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow2_col0" class="data row2 col0" >0.871754</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow2_col1" class="data row2 col1" >-0.420516</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow2_col2" class="data row2 col2" >1</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow2_col3" class="data row2 col3" >0.962757</td>
#     </tr>    <tr>
#         <th id="T_0a562394_b440_11e7_b87d_784f4377b2balevel0_row3" class="row_heading level0 row3" >petal_width</th>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow3_col0" class="data row3 col0" >0.817954</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow3_col1" class="data row3 col1" >-0.356544</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow3_col2" class="data row3 col2" >0.962757</td>
#         <td id="T_0a562394_b440_11e7_b87d_784f4377b2barow3_col3" class="data row3 col3" >1</td>
#     </tr></tbody>
# </table>

# %%
# seaborn provides easy-to-use visualization tools
import seaborn as sns

f, ax = plt.subplots()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=cmap, square=True, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
